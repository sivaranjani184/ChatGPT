# %%
import openai

openai.api_key  = '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'

completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", 
                                          messages=[{"role": "user",
                                                     "content": "Give me 3 ideas for apps I could build with openai apis "}])
print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10032\152383224.py in <module>
# ----> 1 import openai
#       2
#       3 openai.api_key  = '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'
#       4
#       5 completion = openai.ChatCompletion.create(model="gpt-3.5-turbo",
#
# ModuleNotFoundError: No module named 'openai'
