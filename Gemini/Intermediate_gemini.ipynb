# %%
import google.generativeai as genai

# Configure API key
genai.configure(api_key="AIzaSyCUAb9fkan1YMsYwfDZxPUNh5N3wKx7nGE")  
# Initialize conversation
system_msg = input("What type of chatbot would you like to create?\n")

print("Your new assistant is ready!")

# Load the model
model = genai.GenerativeModel("gemini-2.5-flash")

# Start chatbot loop
while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    # Send user input directly (Gemini does not use "role")
    response = model.generate_content(user_input)

    # Extract response
    reply = response.text

    print("\n" + reply + "\n")
# Out:
# C:\Users\SURYA MURUGANANTHAM\AppData\Local\Temp\ipykernel_6908\2311518706.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# What type of chatbot would you like to create?
#  you are a chef bot
# Your new assistant is ready!
#  tell me how to prepare briyani
# Biryani is a beloved, aromatic, and flavorful rice dish that originated in the Indian subcontinent. It's a celebratory meal, often involving layers of fragrant basmati rice, tender meat (or vegetables/paneer), a rich spice blend, and fresh herbs, cooked together "dum" style (sealed and slow-cooked).
#
# There are many regional variations (Hyderabadi, Lucknowi, Kolkata, Thalassery, etc.), but the core principles remain similar. Here, I'll provide a popular *Hyderabadi-style Chicken Biryani* recipe, which is a fantastic starting point.
#
# **Yields:** 4-6 servings
# **Prep time:** 45 minutes (plus 2-4 hours marination)
# **Cook time:** 45-60 minutes
#
# ---
#
# ### **Ingredients:**
#
# **I. For Marinating the Chicken:**
# *   1 kg (about 2.2 lbs) chicken, cut into medium pieces (bone-in preferred)
# *   1 cup plain yogurt (dahi), whisked
# *   2 tbsp ginger-garlic paste
# *   2-3 green chilies, slit or made into a paste (adjust to your spice preference)
# *   1/2 cup fresh mint leaves, chopped
# *   1/2 cup fresh coriander leaves (cilantro), chopped
# *   1 tbsp red chili powder (Kashmiri chili powder for color, or regular for heat)
# *   1 tsp turmeric powder
# *   1.5 tbsp coriander powder
# *   1 tsp cumin powder
# *   1 tsp garam masala powder
# *   1/2 tsp black pepper powder
# *   1/4 cup fried onions (birista) - see instructions below
# *   2 tbsp lemon juice
# *   3-4 tbsp cooking oil (or ghee)
# *   Salt to taste (around 1.5 tsp)
#
# **II. For the Rice (Boiling):**
# *   500g (about 2 cups) good quality Basmati rice
# *   Water (to boil)
# *   3-4 green cardamom pods
# *   2-3 black cardamom pods
# *   2-inch cinnamon stick
# *   4-5 cloves
# *   1 star anise
# *   2 bay leaves
# *   1 tsp cumin seeds (shahi jeera if available)
# *   2 tbsp salt
# *   1 tbsp oil (prevents sticking)
#
# **III. For Layering & Dum (Slow Cooking):**
# *   1/2 cup fried onions (birista) - remaining from above
# *   1/4 cup fresh mint leaves, chopped
# *   1/4 cup fresh coriander leaves, chopped
# *   1/4 cup warm milk mixed with a pinch of saffron strands (or a few drops of yellow/orange food color)
# *   2-3 tbsp ghee (clarified butter)
# *   Optional: A few drops of kewra water or rose water for fragrance
#
# ---
#
# ### **Equipment:**
# *   Large mixing bowl
# *   Heavy-bottomed pot with a tight-fitting lid (or a Dutch oven)
# *   Foil or dough to seal the pot
# *   Large pot for boiling rice
# *   Colander for draining rice
#
# ---
#
# ### **Instructions:**
#
# **Step 1: Prepare the Fried Onions (Birista) & Soak Rice**
# 1.  **Slice Onions:** Thinly slice 3-4 large onions (about 3 cups worth).
# 2.  **Fry Onions:** Heat 1-1.5 cups of oil in a wide pan over medium-high heat. Add the sliced onions and fry, stirring frequently, until they turn golden brown and crispy. This takes about 15-20 minutes. Be careful not to burn them, as they can turn bitter.
# 3.  **Drain & Cool:** Remove the fried onions with a slotted spoon and spread them on a paper towel to drain excess oil and cool. They will crisp up further as they cool. You'll need about 3/4 cup for the recipe; save the rest for garnish.
# 4.  **Soak Rice:** Wash the Basmati rice 2-3 times until the water runs clear. Soak it in enough water for at least 30 minutes (but not more than 45 minutes). This prevents breakage and helps it cook evenly.
#
# **Step 2: Marinate the Chicken**
# 1.  In a large mixing bowl, combine the chicken pieces, whisked yogurt, ginger-garlic paste, green chilies, chopped mint, chopped coriander, red chili powder, turmeric powder, coriander powder, cumin powder, garam masala, black pepper powder, lemon juice, salt, and 1/4 cup of the prepared fried onions. Add 3-4 tbsp of the oil used for frying onions (or ghee).
# 2.  Mix everything thoroughly, ensuring the chicken is well coated.
# 3.  Cover the bowl and refrigerate for at least 2-4 hours, or preferably overnight for best flavor.
#
# **Step 3: Par-cook the Rice**
# 1.  While the chicken marinates, bring a large pot of water to a rolling boil. Add all the whole spices (green cardamom, black cardamom, cinnamon, cloves, star anise, bay leaves, cumin seeds), 2 tbsp salt, and 1 tbsp oil.
# 2.  Drain the soaked Basmati rice and add it to the boiling water.
# 3.  Cook the rice for only 5-7 minutes. It should be about 70-80% cooked, meaning it's softened but still has a slight bite (al dente). Do NOT overcook.
# 4.  Immediately drain the rice through a colander. Discard the whole spices if you wish, or leave them in.
#
# **Step 4: Layering the Biryani (Dum Process)**
# 1.  **Prepare the Pot:** Take a heavy-bottomed pot (like a Dutch oven) that is wide enough to hold the layers. Lightly grease the bottom with ghee.
# 2.  **First Layer (Chicken):** Spread the marinated chicken mixture evenly at the bottom of the pot.
# 3.  **Second Layer (Rice):** Gently layer about half of the par-cooked rice over the chicken.
# 4.  **Garnish:** Sprinkle half of the remaining fried onions, chopped mint, and chopped coriander over the rice. Drizzle with 1 tbsp ghee.
# 5.  **Third Layer (Rice):** Layer the remaining par-cooked rice over the previous layer.
# 6.  **Final Garnish:** Sprinkle the remaining fried onions, chopped mint, and chopped coriander. Drizzle with the saffron milk (or food color mixed with milk), the remaining 1-2 tbsp ghee, and optional kewra/rose water.
#
# **Step 5: Dum Cooking (Slow Cooking)**
# 1.  **Seal the Pot:** Cover the pot tightly with a lid. To ensure a perfect "dum" (steam cooking), you can seal the edges of the lid with a strip of dough made from flour and water, or by placing a piece of aluminum foil between the pot and the lid before placing the lid on top.
# 2.  **Initial Heat:** Place the sealed pot on high heat for 5-7 minutes. This helps build up steam inside.
# 3.  **Low Heat:** Reduce the heat to the lowest possible setting. Cook for another 30-40 minutes.
# 4.  **Rest:** Once the cooking time is up, turn off the heat but do NOT open the lid immediately. Let the biryani rest, undisturbed, for at least 15-20 minutes. This allows the flavors to meld and the steam to distribute evenly.
#
# **Step 6: Serve**
# 1.  Gently open the lid. Using a flat spatula or spoon, carefully scoop the biryani from the bottom upwards, ensuring you get both rice and chicken in each serving. Do not mix vigorously, as this can break the rice grains.
# 2.  Serve hot with raita (yogurt dip), mirchi ka salan (chilli curry), or a simple salad.
#
# ---
#
# ### **Tips for a Perfect Biryani:**
#
# *   **Quality Basmati Rice:** This is crucial. Use aged, good quality Basmati for the best aroma and texture.
# *   **Don't Overcook Rice:** The rice must be par-cooked (70-80% done) to absorb the flavors during the dum process and prevent it from becoming mushy.
# *   **Fried Onions (Birista):** This step is non-negotiable for authentic flavor. Take your time to fry them perfectly golden and crispy.
# *   **Marination:** The longer the chicken marinates, the more tender and flavorful it will be.
# *   **Heavy Bottomed Pot:** This prevents the bottom layer from burning during slow cooking. If you don't have one, you can place a tawa (griddle) under your pot on low heat.
# *   **Tight Seal:** A good seal is essential for "dum" cooking, as it traps the steam and allows the flavors to infuse properly.
# *   **Gentle Mixing:** Always scoop the biryani from the side, mixing gently to keep the rice grains intact.
#
# Enjoy making and savoring your homemade Biryani! It's a labor of love, but absolutely worth it.
