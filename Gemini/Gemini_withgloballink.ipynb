# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-6.14.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (4.10.0)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.136.1-py3-none-any.whl.metadata (28 kB)
# Collecting gradio-client==2.5.0 (from gradio)
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<2.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-1.15.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (2.4.5)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.9-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (3.0.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (12.2.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (2.13.4)
# Collecting pydub<1.0 (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.28-py3-none-any.whl.metadata (2.1 kB)
# Collecting pytz>=2017.2 (from gradio)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (6.0.3)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=0.40.0 (from gradio)
#   Downloading starlette-1.0.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in C:\Anaconda\envs\genai\Lib\site-packages (from gradio) (4.15.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.47.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting fsspec (from gradio-client==2.5.0->gradio)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna>=2.8 in C:\Anaconda\envs\genai\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: sniffio>=1.1 in C:\Anaconda\envs\genai\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Anaconda\envs\genai\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in C:\Anaconda\envs\genai\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Anaconda\envs\genai\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Anaconda\envs\genai\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Anaconda\envs\genai\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Anaconda\envs\genai\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Anaconda\envs\genai\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Anaconda\envs\genai\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Anaconda\envs\genai\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.4)
# Collecting click>=8.2.1 (from typer<1.0,>=0.12->gradio)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer<1.0,>=0.12->gradio)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in C:\Anaconda\envs\genai\Lib\site-packages (from click>=8.2.1->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in C:\Anaconda\envs\genai\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Anaconda\envs\genai\Lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Anaconda\envs\genai\Lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Anaconda\envs\genai\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-6.14.0-py3-none-any.whl (19.7 MB)
#    ---------------------------------------- 0.0/19.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.7 MB 1.7 MB/s eta 0:00:12
#    -- ------------------------------------- 1.0/19.7 MB 1.9 MB/s eta 0:00:10
#    --- ------------------------------------ 1.6/19.7 MB 2.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.4/19.7 MB 2.5 MB/s eta 0:00:07
#    ------ --------------------------------- 3.1/19.7 MB 2.8 MB/s eta 0:00:06
#    ------- -------------------------------- 3.9/19.7 MB 2.9 MB/s eta 0:00:06
#    ---------- ----------------------------- 5.0/19.7 MB 3.1 MB/s eta 0:00:05
#    ------------ --------------------------- 6.0/19.7 MB 3.4 MB/s eta 0:00:05
#    -------------- ------------------------- 7.1/19.7 MB 3.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 8.4/19.7 MB 3.8 MB/s eta 0:00:03
#    ------------------- -------------------- 9.4/19.7 MB 3.9 MB/s eta 0:00:03
#    --------------------- ------------------ 10.7/19.7 MB 4.1 MB/s eta 0:00:03
#    ------------------------ --------------- 12.1/19.7 MB 4.2 MB/s eta 0:00:02
#    --------------------------- ------------ 13.4/19.7 MB 4.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 14.7/19.7 MB 4.5 MB/s eta 0:00:02
#    ------------------------------- -------- 15.7/19.7 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.8/19.7 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 18.1/19.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 19.7/19.7 MB 4.6 MB/s  0:00:04
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
# Downloading fastapi-0.136.1-py3-none-any.whl (117 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.15.0-py3-none-any.whl (663 kB)
#    ---------------------------------------- 0.0/663.6 kB ? eta -:--:--
#    ---------------------------------------- 663.6/663.6 kB 6.4 MB/s  0:00:00
# Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.0 MB 5.0 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/4.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/4.0 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 5.5 MB/s  0:00:00
# Downloading orjson-3.11.9-cp311-cp311-win_amd64.whl (127 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.28-py3-none-any.whl (29 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
# Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl (369 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.47.0-py3-none-any.whl (71 kB)
# Installing collected packages: pytz, pydub, brotli, tomlkit, shellingham, semantic-version, python-multipart, orjson, hf-xet, groovy, fsspec, filelock, click, annotated-doc, uvicorn, starlette, rich, typer, safehttpx, fastapi, huggingface-hub, gradio-client, hf-gradio, gradio
#
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    - --------------------------------------  1/24 [pydub]
#    - --------------------------------------  1/24 [pydub]
#    - --------------------------------------  1/24 [pydub]
#    ----- ----------------------------------  3/24 [tomlkit]
#    ----- ----------------------------------  3/24 [tomlkit]
#    ----- ----------------------------------  3/24 [tomlkit]
#    ----- ----------------------------------  3/24 [tomlkit]
#    ------ ---------------------------------  4/24 [shellingham]
#    ------ ---------------------------------  4/24 [shellingham]
#    -------- -------------------------------  5/24 [semantic-version]
#    ---------- -----------------------------  6/24 [python-multipart]
#    ---------- -----------------------------  6/24 [python-multipart]
#    ---------- -----------------------------  6/24 [python-multipart]
#    ------------- --------------------------  8/24 [hf-xet]
#    ------------- --------------------------  8/24 [hf-xet]
#    --------------- ------------------------  9/24 [groovy]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ---------------- ----------------------- 10/24 [fsspec]
#    ------------------ --------------------- 11/24 [filelock]
#    ------------------ --------------------- 11/24 [filelock]
#    ------------------ --------------------- 11/24 [filelock]
#    ------------------ --------------------- 11/24 [filelock]
#    -------------------- ------------------- 12/24 [click]
#    -------------------- ------------------- 12/24 [click]
#    -------------------- ------------------- 12/24 [click]
#    -------------------- ------------------- 12/24 [click]
#    -------------------- ------------------- 12/24 [click]
#    -------------------- ------------------- 12/24 [click]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ----------------------- ---------------- 14/24 [uvicorn]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    ------------------------- -------------- 15/24 [starlette]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    -------------------------- ------------- 16/24 [rich]
#    ---------------------------- ----------- 17/24 [typer]
#    ---------------------------- ----------- 17/24 [typer]
#    ---------------------------- ----------- 17/24 [typer]
#    ---------------------------- ----------- 17/24 [typer]
#    ---------------------------- ----------- 17/24 [typer]
#    ---------------------------- ----------- 17/24 [typer]
#    ------------------------------ --------- 18/24 [safehttpx]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    ------------------------------- -------- 19/24 [fastapi]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    ----------------------------------- ---- 21/24 [gradio-client]
#    ----------------------------------- ---- 21/24 [gradio-client]
#    ----------------------------------- ---- 21/24 [gradio-client]
#    ------------------------------------ --- 22/24 [hf-gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    -------------------------------------- - 23/24 [gradio]
#    ---------------------------------------- 24/24 [gradio]
#
# Successfully installed annotated-doc-0.0.4 brotli-1.2.0 click-8.3.3 fastapi-0.136.1 filelock-3.29.0 fsspec-2026.4.0 gradio-6.14.0 gradio-client-2.5.0 groovy-0.1.2 hf-gradio-0.4.1 hf-xet-1.5.0 huggingface-hub-1.15.0 orjson-3.11.9 pydub-0.25.1 python-multipart-0.0.28 pytz-2026.2 rich-15.0.0 safehttpx-0.1.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-1.0.0 tomlkit-0.14.0 typer-0.25.1 uvicorn-0.47.0

# %%
import google.generativeai as genai
import gradio as gr

# Configure API key
genai.configure(api_key="AIzaSyCUAb9fkan1YMsYwfDZxPUNh5N3wKx7nGE")  
# Load the model
model = genai.GenerativeModel("gemini-2.5-flash")

# System message (used only for context)
system_msg = "You are a financial expert specializing in real estate investment and negotiation."

# Chatbot function
def CustomGemini(user_input):
    response = model.generate_content(system_msg + "\n" + user_input)
    return response.text  # Extract and return response

# Gradio Interface
demo = gr.Interface(fn=CustomGemini, 
                    inputs="text", 
                    outputs="text", 
                    title="My Saving Assistant")

# Launch the app
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://eab5cb0403f0443b0d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://eab5cb0403f0443b0d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
